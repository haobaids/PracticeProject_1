# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import csv
import requests
from scipy import stats
headers = { 
    'accept': "application/json", 
    'apikey': "6c4626d7ba184b0df5179ac181a5ae83" } 
cities_df = pd.read_csv("./ViolentCrime2017.csv")
cities_df.head()
# Out:
#           State                 City Population Violent\ncrime  \
# 0  Pennsylvania                 Erie     98,887            176
# 1    Washington               Renton    100,015            148
# 2     Wisconsin              Kenosha    100,038            141
# 3       Florida                Davie     100612             97
# 4    New Jersey  Woodbridge Township     100950             51
#
#   Property\ncrime Violent Crime per pop  \
# 0             959                     0
# 1           2,921                     0
# 2           1,042                     0
# 3            1431                     0
# 4             802                     0
#
#   Violent crime rate per 100,000 inhabitants Property crime per pop  \
# 0                                     177.98                   0.01
# 1                                     147.98                   0.03
# 2                                     140.95                   0.01
# 3                                      96.41                   0.01
# 4                                      50.52                   0.01
#
#   Property crime per 100,000 inhabitants
# 0                                 969.79
# 1                                2920.56
# 2                                 1041.6
# 3                                 1422.3
# 4                                 794.45

# %%
base_url ="https://search.onboard-apis.com/areaapi/v2.0.0/state/lookup"
res = requests.get(base_url,headers=headers).json()
res
st_data =pd.DataFrame(res['response']['result']['package']['item'])
st_data.rename(columns={'name':'State','geo_key':'St_geo_key'}, inplace=True)
statedata = st_data[['State','St_geo_key','abbreviation']]
city_table =pd.merge(cities_df, statedata, on="State", how="left")
city_table.head()
# Out:
#           State                 City Population Violent\ncrime  \
# 0  Pennsylvania                 Erie     98,887            176
# 1    Washington               Renton    100,015            148
# 2     Wisconsin              Kenosha    100,038            141
# 3       Florida                Davie     100612             97
# 4    New Jersey  Woodbridge Township     100950             51
#
#   Property\ncrime Violent Crime per pop  \
# 0             959                     0
# 1           2,921                     0
# 2           1,042                     0
# 3            1431                     0
# 4             802                     0
#
#   Violent crime rate per 100,000 inhabitants Property crime per pop  \
# 0                                     177.98                   0.01
# 1                                     147.98                   0.03
# 2                                     140.95                   0.01
# 3                                      96.41                   0.01
# 4                                      50.52                   0.01
#
#   Property crime per 100,000 inhabitants St_geo_key abbreviation
# 0                                 969.79       ST42           PA
# 1                                2920.56       ST53           WA
# 2                                 1041.6       ST55           WI
# 3                                 1422.3       ST12           FL
# 4                                 794.45       ST34           NJ

# %%
appended_new = pd.DataFrame([])
for index, row in city_table.iterrows():
    stgc = row['St_geo_key']
    city = row['City']  
    city_url ="https://search.onboard-apis.com/areaapi/v2.0.0/geoid/lookup/?geoId="+stgc+"&GeoType=PL" 
    
    resc = requests.get(city_url,headers=headers).json()
    city_data = pd.DataFrame(resc['response']['result']['package']['item'])
    
    new = city_data.loc[city_data['name'] == city]      
    appended_new = appended_new.append(new)
    
appended_new.head()
# Out:
#          area area_unit    geo_key       id        name type
# 1747  19.3683   sq. mi.  PL4224000  4224000        Erie   PL
# 601   23.6186   sq. mi.  PL5357745  5357745      Renton   PL
# 752   27.8249   sq. mi.  PL5539225  5539225     Kenosha   PL
# 867   35.6799   sq. mi.  PL1216475  1216475       Davie   PL
# 671   41.9473   sq. mi.  PL1871000  1871000  South Bend   PL

# %%
city_table1 =pd.merge(city_table, appended_new, left_on=['City'], right_on=['name'])
city_table1.head()
# Out:
#           State        City Population Violent\ncrime Property\ncrime  \
# 0  Pennsylvania        Erie     98,887            176             959
# 1    Washington      Renton    100,015            148           2,921
# 2     Wisconsin     Kenosha    100,038            141           1,042
# 3       Florida       Davie     100612             97            1431
# 4       Indiana  South Bend     101240            465            2201
#
#   Violent Crime per pop Violent crime rate per 100,000 inhabitants  \
# 0                     0                                     177.98
# 1                     0                                     147.98
# 2                     0                                     140.95
# 3                     0                                      96.41
# 4                     0                                      459.3
#
#   Property crime per pop Property crime per 100,000 inhabitants St_geo_key  \
# 0                   0.01                                 969.79       ST42
# 1                   0.03                                2920.56       ST53
# 2                   0.01                                 1041.6       ST55
# 3                   0.01                                 1422.3       ST12
# 4                   0.02                                2174.04       ST18
#
#   abbreviation     area area_unit    geo_key       id        name type
# 0           PA  19.3683   sq. mi.  PL4224000  4224000        Erie   PL
# 1           WA  23.6186   sq. mi.  PL5357745  5357745      Renton   PL
# 2           WI  27.8249   sq. mi.  PL5539225  5539225     Kenosha   PL
# 3           FL  35.6799   sq. mi.  PL1216475  1216475       Davie   PL
# 4           IN  41.9473   sq. mi.  PL1871000  1871000  South Bend   PL

# %%
appended_main = pd.DataFrame([])

for index, row in city_table1.iterrows():
    cgc = row['geo_key']
  
    base_url="https://search.onboard-apis.com/communityapi/v2.0.0/area/full?AreaId="+cgc
    
    resct = requests.get( base_url,headers=headers).json()
    city_data2 = pd.DataFrame(resct['response']['result']['package']['item'])
    appended_main = appended_main.append(city_data2)
 
    #appended_new = appended_new.append(new)
    
# cocrmcyasst : Assault Risk (County)
# cocrmcytotc : Total Crime Risk (County)
crime = appended_main[['name','latitude','geo_key','longitude','cocrmcyasst','cocrmcytotc']]
crime.head()
# Out:
#          name   latitude    geo_key    longitude cocrmcyasst cocrmcytotc
# 0        Erie  42.115943  PL4224000   -80.073991          79          83
# 0      Renton  47.478434  PL5357745  -122.183594          59         127
# 0     Kenosha  42.584065  PL5539225   -87.852219          39          70
# 0       Davie  26.080792  PL1216475   -80.280488         103         112
# 0  South Bend  41.670857  PL1871000   -86.253333          41         119

# %%
crime0 =pd.merge(city_table, crime, left_on=['City'], right_on=['name'])
crime0.head()
# Out:
#           State        City Population Violent\ncrime Property\ncrime  \
# 0  Pennsylvania        Erie     98,887            176             959
# 1    Washington      Renton    100,015            148           2,921
# 2     Wisconsin     Kenosha    100,038            141           1,042
# 3       Florida       Davie     100612             97            1431
# 4       Indiana  South Bend     101240            465            2201
#
#   Violent Crime per pop Violent crime rate per 100,000 inhabitants  \
# 0                     0                                     177.98
# 1                     0                                     147.98
# 2                     0                                     140.95
# 3                     0                                      96.41
# 4                     0                                      459.3
#
#   Property crime per pop Property crime per 100,000 inhabitants St_geo_key  \
# 0                   0.01                                 969.79       ST42
# 1                   0.03                                2920.56       ST53
# 2                   0.01                                 1041.6       ST55
# 3                   0.01                                 1422.3       ST12
# 4                   0.02                                2174.04       ST18
#
#   abbreviation        name   latitude    geo_key    longitude cocrmcyasst  \
# 0           PA        Erie  42.115943  PL4224000   -80.073991          79
# 1           WA      Renton  47.478434  PL5357745  -122.183594          59
# 2           WI     Kenosha  42.584065  PL5539225   -87.852219          39
# 3           FL       Davie  26.080792  PL1216475   -80.280488         103
# 4           IN  South Bend  41.670857  PL1871000   -86.253333          41
#
#   cocrmcytotc
# 0          83
# 1         127
# 2          70
# 3         112
# 4         119

# %%
crime2 = crime0.reset_index()
crime1 = crime2.drop(columns=['index'])
# crime1 = crime1.iloc[0:9,:]
crime1.shape
# Out:
# (325, 17)

# %%
schools = pd.DataFrame(columns=['city_name','latitude','longitude','geo_key','cocrmcyasst','cocrmcytotc','school_id'])
schoolCount = 0
for index, row in crime1.iterrows():
    print(f"Processing City Name: {row['name']}")
    lat = row['latitude']
    lng = row['longitude']  
    sch_url="https://search.onboard-apis.com/propertyapi/v1.0.0/school/snapshot?latitude="+lat+"&longitude="+lng+"&radius=50&filetypetext=public"
    try:
        response = requests.get(sch_url,headers=headers)
        if response.status_code == requests.codes.ok:
            resch = response.json()
            for a_school in resch['school']:
                schools.loc[schoolCount] = [row['name'],row['latitude'], row['longitude'],row['geo_key'],row['cocrmcyasst'],row['cocrmcytotc'],a_school['Identifier']['OBInstID'] ]
                schoolCount += 1
        else:
            print("School not found. Skipping...")
    except:         
        print("Unknown exception...")
        pass

schools.head()
# Out:
# Processing City Name: Erie
# Processing City Name: Renton
# Processing City Name: Kenosha
# Processing City Name: Davie
# Processing City Name: South Bend
# Processing City Name: Las Cruces
# Processing City Name: Tyler
# Processing City Name: Lakeland
# Processing City Name: Rialto
# Processing City Name: Clovis
# Processing City Name: Sandy Springs
# Processing City Name: El Cajon
# Processing City Name: San Mateo
# Processing City Name: Santa Maria
# Processing City Name: Lewisville
# Unknown exception...
# Processing City Name: West Palm Beach
# Processing City Name: Green Bay
# Processing City Name: Wichita Falls
# Processing City Name: College Station
# Processing City Name: Burbank
# Processing City Name: Burbank
# Processing City Name: Broken Arrow
# Processing City Name: Palm Bay
# Processing City Name: Pearland
# Processing City Name: Daly City
# Processing City Name: Norwalk
# Processing City Name: Everett
# Processing City Name: Pompano Beach
# Unknown exception...
# Processing City Name: Pueblo
# Processing City Name: West Covina
# Processing City Name: Waterbury
# Processing City Name: North Charleston
# Processing City Name: Murrieta
# Processing City Name: High Point
# Processing City Name: Richmond
# Processing City Name: Richmond
# Processing City Name: Richmond
# Processing City Name: Richmond
# Processing City Name: Richmond
# Processing City Name: Richmond
# Processing City Name: Richmond
# Processing City Name: Richmond
# Processing City Name: Billings
# Processing City Name: Antioch
# Processing City Name: Manchester
# Processing City Name: Lowell
# Processing City Name: Cambridge
# Processing City Name: Richardson
# Processing City Name: Clearwater
# Unknown exception...
# Processing City Name: Elgin
# Processing City Name: Inglewood
# Processing City Name: Rochester
# Processing City Name: Rochester
# Processing City Name: Rochester
# Processing City Name: Rochester
# Processing City Name: Rochester
# Processing City Name: Rochester
# Processing City Name: Rochester
# Processing City Name: Rochester
# Processing City Name: Fairfield
# Processing City Name: Miami Gardens
# Processing City Name: Costa Mesa
# Processing City Name: Westminster
# Processing City Name: Carlsbad
# Processing City Name: Lansing
# Processing City Name: Downey
# Processing City Name: Provo
# Processing City Name: Arvada
# Processing City Name: Wilmington
# Processing City Name: Round Rock
# Processing City Name: Peoria
# Processing City Name: Peoria
# Processing City Name: Peoria
# Processing City Name: Peoria
# Processing City Name: Peoria
# Unknown exception...
# Processing City Name: Peoria
# Processing City Name: Peoria
# Processing City Name: Peoria
# Processing City Name: El Monte
# Processing City Name: Beaumont
# Processing City Name: Independence
# Processing City Name: Fargo
# Processing City Name: Odessa
# Processing City Name: Ann Arbor
# Processing City Name: Columbia
# Processing City Name: Columbia
# Processing City Name: Columbia
# Processing City Name: Columbia
# Processing City Name: Columbia
# Processing City Name: Columbia
# Processing City Name: Columbia
# Processing City Name: Columbia
# Processing City Name: Allentown
# Processing City Name: Berkeley
# Processing City Name: Evansville
# Processing City Name: Vallejo
# Processing City Name: Abilene
# Processing City Name: Victorville
# Processing City Name: Santa Clara
# Processing City Name: Murfreesboro
# Processing City Name: Hartford
# Processing City Name: Topeka
# Processing City Name: Kent
# Processing City Name: Lafayette
# Processing City Name: Simi Valley
# Processing City Name: Concord
# Processing City Name: Elizabeth
# Processing City Name: Coral Springs
# Processing City Name: Stamford
# Unknown exception...
# Processing City Name: Thousand Oaks
# Processing City Name: New Haven
# Processing City Name: Visalia
# Processing City Name: Carrollton
# Processing City Name: Denton
# Processing City Name: Waco
# Processing City Name: Charleston
# Processing City Name: Midland
# Processing City Name: Thornton
# Processing City Name: Olathe
# Processing City Name: Warren
# Processing City Name: Hampton
# Processing City Name: Miramar
# Processing City Name: Killeen
# Processing City Name: Orange
# Processing City Name: McAllen
# Processing City Name: Dayton
# Processing City Name: Pasadena
# Processing City Name: Pasadena
# Processing City Name: Pasadena
# Processing City Name: Pasadena
# Processing City Name: Pasadena
# Processing City Name: Pasadena
# Processing City Name: Pasadena
# Processing City Name: Pasadena
# Processing City Name: Syracuse
# Processing City Name: Mesquite
# Processing City Name: Mesquite
# Processing City Name: Paterson
# Processing City Name: Naperville
# Unknown exception...
# Processing City Name: Joliet
# Processing City Name: Rockford
# Processing City Name: Bridgeport
# Processing City Name: Torrance
# Processing City Name: Hollywood
# Unknown exception...
# Processing City Name: Clarksville
# Processing City Name: Lakewood
# Processing City Name: Escondido
# Processing City Name: Sunnyvale
# Processing City Name: Frisco
# Processing City Name: Alexandria
# Processing City Name: Springfield
# Processing City Name: Springfield
# Processing City Name: Springfield
# Processing City Name: Springfield
# Processing City Name: Springfield
# Processing City Name: Springfield
# Processing City Name: Springfield
# Processing City Name: Springfield
# Processing City Name: Pomona
# Processing City Name: Hayward
# Processing City Name: Salinas
# Processing City Name: Palmdale
# Processing City Name: Fort Collins
# Processing City Name: Cary
# Processing City Name: Eugene
# Processing City Name: Lancaster
# Processing City Name: Salem
# Processing City Name: McKinney
# Processing City Name: Elk Grove
# Processing City Name: Pembroke Pines
# Processing City Name: Ontario
# Processing City Name: Jackson
# Processing City Name: Vancouver
# Processing City Name: Sioux Falls
# Processing City Name: Chattanooga
# Processing City Name: Tempe
# Processing City Name: Santa Rosa
# Unknown exception...
# Processing City Name: Garden Grove
# Processing City Name: Oceanside
# Processing City Name: Port St. Lucie
# Processing City Name: Rancho Cucamonga
# Processing City Name: Fort Lauderdale
# Processing City Name: Newport News
# Processing City Name: Worcester
# Processing City Name: Brownsville
# Processing City Name: Knoxville
# Processing City Name: Overland Park
# Processing City Name: Grand Prairie
# Processing City Name: Tallahassee
# Processing City Name: Huntsville
# Processing City Name: Grand Rapids
# Processing City Name: Akron
# Processing City Name: Shreveport
# Processing City Name: Little Rock
# Processing City Name: Amarillo
# Processing City Name: Aurora
# Processing City Name: Aurora
# Processing City Name: Aurora
# Processing City Name: Aurora
# Processing City Name: Aurora
# Processing City Name: Aurora
# Processing City Name: Aurora
# Processing City Name: Aurora
# Processing City Name: Yonkers
# Processing City Name: Huntington Beach
# Processing City Name: Fayetteville
# Processing City Name: Moreno Valley
# Processing City Name: Tacoma
# Processing City Name: Fontana
# Processing City Name: Oxnard
# Processing City Name: Modesto
# Processing City Name: Santa Clarita
# Processing City Name: Spokane
# Processing City Name: San Bernardino
# Processing City Name: Baton Rouge
# Processing City Name: Fremont
# Processing City Name: Scottsdale
# Processing City Name: North Las Vegas
# Processing City Name: Chesapeake
# Processing City Name: Irving
# Processing City Name: Garland
# Processing City Name: Hialeah
# Processing City Name: Reno
# Processing City Name: Norfolk
# Processing City Name: Lubbock
# Processing City Name: Gilbert
# Processing City Name: Madison
# Processing City Name: St. Petersburg
# Processing City Name: Laredo
# Processing City Name: Buffalo
# Processing City Name: Irvine
# Processing City Name: Chandler
# Processing City Name: Fort Wayne
# Processing City Name: Jersey City
# Processing City Name: Chula Vista
# Processing City Name: Orlando
# Processing City Name: Lincoln
# Processing City Name: Henderson
# Processing City Name: Greensboro
# Processing City Name: Cincinnati
# Processing City Name: St. Paul
# Processing City Name: Anchorage
# Processing City Name: Stockton
# Processing City Name: Pittsburgh
# Processing City Name: St. Louis
# Processing City Name: Riverside
# Processing City Name: Corpus Christi
# Processing City Name: Santa Ana
# Processing City Name: Anaheim
# Processing City Name: Tampa
# Processing City Name: Bakersfield
# Processing City Name: New Orleans
# Processing City Name: Tulsa
# Processing City Name: Minneapolis
# Processing City Name: Oakland
# Processing City Name: Miami
# Processing City Name: Omaha
# Processing City Name: Colorado Springs
# Processing City Name: Virginia Beach
# Processing City Name: Atlanta
# Processing City Name: Mesa
# Processing City Name: Kansas City
# Processing City Name: Long Beach
# Processing City Name: Sacramento
# Processing City Name: Fresno
# Processing City Name: Tucson
# Processing City Name: Albuquerque
# Processing City Name: Milwaukee
# Processing City Name: Baltimore
# Unknown exception...
# Processing City Name: Oklahoma City
# Processing City Name: Memphis
# Processing City Name: Detroit
# Processing City Name: Denver
# Processing City Name: Seattle
# Processing City Name: El Paso
# Processing City Name: Fort Worth
# Unknown exception...
# Processing City Name: Columbus
# Processing City Name: San Francisco
# Processing City Name: Jacksonville
# Processing City Name: Austin
# Processing City Name: San Jose
# Processing City Name: Dallas
# Processing City Name: San Diego
# Processing City Name: San Antonio
# Processing City Name: Philadelphia
# Processing City Name: Houston
# Processing City Name: Chicago
# Processing City Name: Los Angeles
# Processing City Name: New York
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Unknown exception...
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
# Processing City Name: Plano
#   city_name   latitude   longitude    geo_key cocrmcyasst cocrmcytotc  \
# 0      Erie  42.115943  -80.073991  PL4224000          79          83
# 1      Erie  42.115943  -80.073991  PL4224000          79          83
# 2      Erie  42.115943  -80.073991  PL4224000          79          83
# 3      Erie  42.115943  -80.073991  PL4224000          79          83
# 4      Erie  42.115943  -80.073991  PL4224000          79          83
#
#   school_id
# 0  04791835
# 1  05286986
# 2  02107991
# 3  00909157
# 4  00909016

# %%
schools.shape
# Out:
# (3137, 7)

# %%
for index, row in schools.iterrows():
    city_name = row['city_name']
    school_id = row['school_id']         
    sch_url="https://search.onboard-apis.com/propertyapi/v1.0.0/school/detail?id="+school_id
    try:
        response = requests.get(sch_url,headers=headers)
        if response.status_code == requests.codes.ok:
            resch = response.json()
            #Studentteacher is School enrollment student teacher
            schools.loc[index,'studentteacherratio'] = resch['school'][0]['SchoolProfileAndDistrictInfo']['SchoolEnrollment']['Studentteacher']
            schools.loc[index,'highschool'] = resch['school'][0]['SchoolProfileAndDistrictInfo']['SchoolSummary']['High']
#             print(resch['school'][0]['SchoolProfileAndDistrictInfo']['SchoolEnrollment']['Studentteacher'])
        else:
            print("Data not found. Skipping...") 
    except:         
        print(f"Unknown exception for city {city_name} school {school_id}...")
        pass
schools.head()
# Out:
# Unknown exception for city Renton school 01101695...
# Unknown exception for city Davie school 01827033...
# Unknown exception for city Las Cruces school 01171846...
# Unknown exception for city Las Cruces school 5700100084...
# Unknown exception for city Rialto school 00107842...
# Unknown exception for city Clovis school 00056700...
# Unknown exception for city El Cajon school 00110306...
# Unknown exception for city San Mateo school 00123145...
# Unknown exception for city San Mateo school 5700047071...
# Unknown exception for city Wichita Falls school 5700046487...
# Unknown exception for city Burbank school 00128391...
# Unknown exception for city Burbank school 00125583...
# Unknown exception for city Broken Arrow school 5700073781...
# Unknown exception for city Daly City school 00121898...
# Unknown exception for city Everett school 01110488...
# Unknown exception for city Pueblo school 5700080229...
# Unknown exception for city Pueblo school 00156116...
# Unknown exception for city West Covina school 5700050268...
# Unknown exception for city High Point school 00637770...
# Unknown exception for city High Point school 00637706...
# Unknown exception for city Richmond school 00055201...
# Unknown exception for city Richmond school 5700055002...
# Unknown exception for city Richmond school 5700092618...
# Unknown exception for city Richmond school 04932948...
# Unknown exception for city Richmond school 00055201...
# Unknown exception for city Richmond school 01088134...
# Unknown exception for city Richmond school 5700058415...
# Unknown exception for city Richmond school 5700110131...
# Unknown exception for city Richmond school 01087958...
# Unknown exception for city Antioch school 00053411...
# Unknown exception for city Lowell school 04924745...
# Unknown exception for city Cambridge school 02046311...
# Unknown exception for city Cambridge school 5700100396...
# Unknown exception for city Cambridge school 5700061477...
# Unknown exception for city Elgin school 00298166...
# Unknown exception for city Inglewood school 00070770...
# Unknown exception for city Rochester school 01841168...
# Unknown exception for city Rochester school 00542345...
# Unknown exception for city Rochester school 5700065937...
# Unknown exception for city Rochester school 5700054518...
# Unknown exception for city Miami Gardens school 00185521...
# Unknown exception for city Downey school 00068492...
# Unknown exception for city Arvada school 00151790...
# Unknown exception for city Wilmington school 00642995...
# Unknown exception for city Round Rock school 01061095...
# Unknown exception for city Peoria school 00313170...
# Unknown exception for city Peoria school 00313170...
# Unknown exception for city Peoria school 00313120...
# Unknown exception for city Peoria school 03399290...
# Unknown exception for city Fargo school 00652691...
# Unknown exception for city Fargo school 00652653...
# Unknown exception for city Ann Arbor school 00515823...
# Unknown exception for city Columbia school 00556009...
# Unknown exception for city Columbia school 00555990...
# Unknown exception for city Columbia school 00556009...
# Unknown exception for city Evansville school 00354681...
# Unknown exception for city Victorville school 00109802...
# Unknown exception for city Murfreesboro school 5700069098...
# Unknown exception for city Topeka school 00374930...
# Unknown exception for city Kent school 04019912...
# Unknown exception for city Simi Valley school 00140844...
# Unknown exception for city Simi Valley school 00140612...
# Unknown exception for city Concord school 00443050...
# Unknown exception for city Concord school 5700071848...
# Unknown exception for city Thousand Oaks school 00141020...
# Unknown exception for city Waco school 01040209...
# Unknown exception for city Thornton school 00142971...
# Unknown exception for city Thornton school 00142878...
# Unknown exception for city Olathe school 00364674...
# Unknown exception for city Olathe school 00364662...
# Unknown exception for city McAllen school 02043345...
# Unknown exception for city Dayton school 5700091940...
# Unknown exception for city Pasadena school 00080581...
# Unknown exception for city Pasadena school 01026758...
# Unknown exception for city Pasadena school 5700100712...
# Unknown exception for city Pasadena school 01026928...
# Unknown exception for city Mesquite school 01011416...
# Unknown exception for city Paterson school 00697043...
# Unknown exception for city Torrance school 00082670...
# Unknown exception for city Clarksville school 00987135...
# Unknown exception for city Lakewood school 00152366...
# Unknown exception for city Alexandria school 01083782...
# Unknown exception for city Springfield school 04034974...
# Unknown exception for city Pomona school 05319442...
# Unknown exception for city Salinas school 5700099159...
# Unknown exception for city Palmdale school 05011183...
# Unknown exception for city Eugene school 00873730...
# Unknown exception for city Salem school 00877279...
# Unknown exception for city Salem school 00877231...
# Unknown exception for city Pembroke Pines school 5700092265...
# Unknown exception for city Ontario school 00108420...
# Unknown exception for city Vancouver school 10775690...
# Unknown exception for city Garden Grove school 00096231...
# Unknown exception for city Oceanside school 04288565...
# Unknown exception for city Port St. Lucie school 5700067871...
# Unknown exception for city Port St. Lucie school 5700066148...
# Unknown exception for city Rancho Cucamonga school 04282078...
# Unknown exception for city Knoxville school 5700050220...
# Unknown exception for city Knoxville school 00984511...
# Unknown exception for city Grand Rapids school 5700100994...
# Unknown exception for city Akron school 5700085027...
# Unknown exception for city Little Rock school 00031798...
# Unknown exception for city Amarillo school 01047324...
# Unknown exception for city Aurora school 01541863...
# Unknown exception for city Aurora school 02855928...
# Unknown exception for city Aurora school 01526722...
# Unknown exception for city Aurora school 01541863...
# Unknown exception for city Aurora school 5700078008...
# Unknown exception for city Aurora school 01526722...
# Unknown exception for city Huntington Beach school 00096815...
# Unknown exception for city Huntington Beach school 5700080160...
# Unknown exception for city Fontana school 02179205...
# Unknown exception for city Oxnard school 00140131...
# Unknown exception for city Chesapeake school 5700045652...
# Unknown exception for city Garland school 01010539...
# Unknown exception for city Lubbock school 01038713...
# Unknown exception for city Laredo school 01059195...
# Unknown exception for city Buffalo school 00723159...
# Unknown exception for city Buffalo school 04367020...
# Unknown exception for city Irvine school 01543287...
# Unknown exception for city Irvine school 00098605...
# Unknown exception for city Jersey City school 04758077...
# Unknown exception for city Chula Vista school 04035100...
# Unknown exception for city Chula Vista school 5700070453...
# Unknown exception for city Henderson school 04945488...
# Unknown exception for city Pittsburgh school 04839619...
# Unknown exception for city Riverside school 10768582...
# Unknown exception for city Corpus Christi school 01044217...
# Unknown exception for city Santa Ana school 00098813...
# Unknown exception for city Tampa school 00192471...
# Unknown exception for city Miami school 00186446...
# Unknown exception for city Kansas City school 04880864...
# Unknown exception for city Fresno school 5700086220...
# Unknown exception for city Fresno school 00057285...
# Unknown exception for city Fresno school 04943727...
# Unknown exception for city Tucson school 00044484...
# Unknown exception for city Oklahoma City school 5700084182...
# Unknown exception for city Oklahoma City school 04914324...
# Unknown exception for city Denver school 00147361...
# Unknown exception for city Denver school 00147335...
# Unknown exception for city San Francisco school 00116427...
# Unknown exception for city San Francisco school 00117160...
# Unknown exception for city San Francisco school 5700084195...
# Unknown exception for city San Jose school 5700080797...
# Unknown exception for city Dallas school 5700107005...
# Unknown exception for city San Diego school 00113322...
# Unknown exception for city San Diego school 00112574...
# Unknown exception for city San Diego school 5700071266...
# Unknown exception for city Houston school 01418436...
# Unknown exception for city Los Angeles school 00074984...
# Unknown exception for city New York school 00745195...
# Unknown exception for city New York school 00750255...
# Unknown exception for city Plano school 02108000...
# Unknown exception for city Plano school 01824108...
# Unknown exception for city Plano school 01401366...
# Unknown exception for city Plano school 02225610...
# Unknown exception for city Plano school 01006435...
# Unknown exception for city Plano school 02225610...
# Unknown exception for city Plano school 01824122...
# Unknown exception for city Plano school 01824108...
# Unknown exception for city Plano school 01006435...
# Unknown exception for city Plano school 5700075491...
# Unknown exception for city Plano school 01401366...
# Unknown exception for city Plano school 01006435...
# Unknown exception for city Plano school 02225610...
#   city_name   latitude   longitude    geo_key cocrmcyasst cocrmcytotc  \
# 0      Erie  42.115943  -80.073991  PL4224000          79          83
# 1      Erie  42.115943  -80.073991  PL4224000          79          83
# 2      Erie  42.115943  -80.073991  PL4224000          79          83
# 3      Erie  42.115943  -80.073991  PL4224000          79          83
# 4      Erie  42.115943  -80.073991  PL4224000          79          83
#
#   school_id studentteacherratio highschool
# 0  04791835                  17          Y
# 1  05286986                  12          Y
# 2  02107991                  11       None
# 3  00909157                  11       None
# 4  00909016                  14       None

# %%
schools2 =pd.merge(city_table, schools, left_on=['City'], right_on=['city_name'])
schools2.head()
# Out:
#           State  City Population Violent\ncrime Property\ncrime  \
# 0  Pennsylvania  Erie     98,887            176             959
# 1  Pennsylvania  Erie     98,887            176             959
# 2  Pennsylvania  Erie     98,887            176             959
# 3  Pennsylvania  Erie     98,887            176             959
# 4  Pennsylvania  Erie     98,887            176             959
#
#   Violent Crime per pop Violent crime rate per 100,000 inhabitants  \
# 0                     0                                     177.98
# 1                     0                                     177.98
# 2                     0                                     177.98
# 3                     0                                     177.98
# 4                     0                                     177.98
#
#   Property crime per pop Property crime per 100,000 inhabitants St_geo_key  \
# 0                   0.01                                 969.79       ST42
# 1                   0.01                                 969.79       ST42
# 2                   0.01                                 969.79       ST42
# 3                   0.01                                 969.79       ST42
# 4                   0.01                                 969.79       ST42
#
#   abbreviation city_name   latitude   longitude    geo_key cocrmcyasst  \
# 0           PA      Erie  42.115943  -80.073991  PL4224000          79
# 1           PA      Erie  42.115943  -80.073991  PL4224000          79
# 2           PA      Erie  42.115943  -80.073991  PL4224000          79
# 3           PA      Erie  42.115943  -80.073991  PL4224000          79
# 4           PA      Erie  42.115943  -80.073991  PL4224000          79
#
#   cocrmcytotc school_id studentteacherratio highschool
# 0          83  04791835                  17          Y
# 1          83  05286986                  12          Y
# 2          83  02107991                  11       None
# 3          83  00909157                  11       None
# 4          83  00909016                  14       None

# %%
#remove data when student teacher ratio is not reported
schools_data = schools2
# schools_data2 = schools_data.loc[schools_data['studentteacherratio'] != 'Not Reported', :] 
schools_data2 = schools_data.loc[(schools_data['studentteacherratio'] != 'Not Reported') & (schools_data['highschool'] == 'Y'), :] 
schools_data2.head()
# Out:
#            State    City Population Violent\ncrime Property\ncrime  \
# 0   Pennsylvania    Erie     98,887            176             959
# 1   Pennsylvania    Erie     98,887            176             959
# 6   Pennsylvania    Erie     98,887            176             959
# 13    Washington  Renton    100,015            148           2,921
# 39       Florida   Davie     100612             97            1431
#
#    Violent Crime per pop Violent crime rate per 100,000 inhabitants  \
# 0                      0                                     177.98
# 1                      0                                     177.98
# 6                      0                                     177.98
# 13                     0                                     147.98
# 39                     0                                      96.41
#
#    Property crime per pop Property crime per 100,000 inhabitants St_geo_key  \
# 0                    0.01                                 969.79       ST42
# 1                    0.01                                 969.79       ST42
# 6                    0.01                                 969.79       ST42
# 13                   0.03                                2920.56       ST53
# 39                   0.01                                 1422.3       ST12
#
#    abbreviation city_name   latitude    longitude    geo_key cocrmcyasst  \
# 0            PA      Erie  42.115943   -80.073991  PL4224000          79
# 1            PA      Erie  42.115943   -80.073991  PL4224000          79
# 6            PA      Erie  42.115943   -80.073991  PL4224000          79
# 13           WA    Renton  47.478434  -122.183594  PL5357745          59
# 39           FL     Davie  26.080792   -80.280488  PL1216475         103
#
#    cocrmcytotc school_id studentteacherratio highschool
# 0           83  04791835                  17          Y
# 1           83  05286986                  12          Y
# 6           83  00909121                  13          Y
# 13         127  01101841                  21          Y
# 39         112  00183523                  20          Y

# %%
schools_data2.shape
# Out:
# (634, 20)

# %%
#convert student teacher ratio column data to integer
schools_data2['studentteacherratio'] = schools_data2['studentteacherratio'].astype(str).astype(int)
schools_data2['cocrmcyasst'] = schools_data2['cocrmcyasst'].astype(str).astype(int)
schools_data2['cocrmcytotc'] = schools_data2['cocrmcytotc'].astype(str).astype(int)

schools_data2.head()
# Out:
# C:\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#            State    City Population Violent\ncrime Property\ncrime  \
# 0   Pennsylvania    Erie     98,887            176             959
# 1   Pennsylvania    Erie     98,887            176             959
# 6   Pennsylvania    Erie     98,887            176             959
# 13    Washington  Renton    100,015            148           2,921
# 39       Florida   Davie     100612             97            1431
#
#    Violent Crime per pop Violent crime rate per 100,000 inhabitants  \
# 0                      0                                     177.98
# 1                      0                                     177.98
# 6                      0                                     177.98
# 13                     0                                     147.98
# 39                     0                                      96.41
#
#    Property crime per pop Property crime per 100,000 inhabitants St_geo_key  \
# 0                    0.01                                 969.79       ST42
# 1                    0.01                                 969.79       ST42
# 6                    0.01                                 969.79       ST42
# 13                   0.03                                2920.56       ST53
# 39                   0.01                                 1422.3       ST12
#
#    abbreviation city_name   latitude    longitude    geo_key  cocrmcyasst  \
# 0            PA      Erie  42.115943   -80.073991  PL4224000           79
# 1            PA      Erie  42.115943   -80.073991  PL4224000           79
# 6            PA      Erie  42.115943   -80.073991  PL4224000           79
# 13           WA    Renton  47.478434  -122.183594  PL5357745           59
# 39           FL     Davie  26.080792   -80.280488  PL1216475          103
#
#     cocrmcytotc school_id  studentteacherratio highschool
# 0            83  04791835                   17          Y
# 1            83  05286986                   12          Y
# 6            83  00909121                   13          Y
# 13          127  01101841                   21          Y
# 39          112  00183523                   20          Y

# %%
# calculate average student teacher ratio for each city
schools_city = schools_data2.groupby(['City','State'])['cocrmcyasst','cocrmcytotc','studentteacherratio'].mean()
schools_city.head()
# Out:
#                           cocrmcyasst  cocrmcytotc  studentteacherratio
# City        State
# Abilene     Texas               105.0        101.0                14.00
# Akron       Ohio                 54.0         85.0                20.75
# Albuquerque New Mexico          248.0        207.0                10.50
# Alexandria  Virginia             68.0        106.0                14.50
# Allentown   Pennsylvania         65.0         78.0                13.50

# %%
schools_city2 = schools_city.reset_index()
schools_city2.head()
# Out:
#           City         State  cocrmcyasst  cocrmcytotc  studentteacherratio
# 0      Abilene         Texas        105.0        101.0                14.00
# 1        Akron          Ohio         54.0         85.0                20.75
# 2  Albuquerque    New Mexico        248.0        207.0                10.50
# 3   Alexandria      Virginia         68.0        106.0                14.50
# 4    Allentown  Pennsylvania         65.0         78.0                13.50

# %%
#get percet of high school gradute or higher data
base_url = 'https://odn.data.socrata.com/resource/8apn-rhyh.json?&variable=percent_high_school_graduate_or_higher&type=place&year=2017&$limit=1500000'
headers = {
    'apikey': "y7qEzTXmdu4mI7zRlsejOJgpF" }

response = requests.get(base_url, headers=headers).json()
test=pd.DataFrame(response)
states = [row.split(", ")[1] for row in test.name]
cities = [row.split(", ")[0] for row in test.name]
test["City"] = cities
test["State"] = states
test.replace(" city","",regex=True, inplace=True)
# new = test.loc[(test['State'] == 'Michigan')]
# new2 = new.loc[(new['name']=='Detroit city, Michigan')]
graduate=test.replace(" CDP","",regex=True, inplace=False)

graduate.head()
# Out:
#                  id                      name   type value  \
# 0  1600000US2642460    Keego Harbor, Michigan  place  91.7
# 1  1600000US4873057    Timberwood Park, Texas  place  93.9
# 2  1600000US1818550       Dover Hill, Indiana  place   100
# 3  1600000US5464516  Poca town, West Virginia  place  89.5
# 4  1600000US2060825      Roeland Park, Kansas  place  96.8
#
#                                  variable  year             City  \
# 0  percent_high_school_graduate_or_higher  2017     Keego Harbor
# 1  percent_high_school_graduate_or_higher  2017  Timberwood Park
# 2  percent_high_school_graduate_or_higher  2017       Dover Hill
# 3  percent_high_school_graduate_or_higher  2017        Poca town
# 4  percent_high_school_graduate_or_higher  2017     Roeland Park
#
#            State
# 0       Michigan
# 1          Texas
# 2        Indiana
# 3  West Virginia
# 4         Kansas

# %%
graduate.shape
# Out:
# (29567, 8)

# %%
#convert number data type for 'value'
graduate['value'] = graduate['value'].astype(float)

# %%
schools_city3 =pd.merge(city_table, schools_city2, left_on=['City','State'], right_on=['City','State'])
schools_all =pd.merge(schools_city3, graduate, how = 'inner', left_on=['City','State'], right_on=['City','State'])
schools_all.head()
# Out:
#           State        City Population Violent\ncrime Property\ncrime  \
# 0  Pennsylvania        Erie     98,887            176             959
# 1    Washington      Renton    100,015            148           2,921
# 2       Indiana  South Bend     101240            465            2201
# 3    New Mexico  Las Cruces     102227            126            2351
# 4         Texas       Tyler    102,481            206           2,002
#
#   Violent Crime per pop Violent crime rate per 100,000 inhabitants  \
# 0                     0                                     177.98
# 1                     0                                     147.98
# 2                     0                                      459.3
# 3                     0                                     123.26
# 4                     0                                     201.01
#
#   Property crime per pop Property crime per 100,000 inhabitants St_geo_key  \
# 0                   0.01                                 969.79       ST42
# 1                   0.03                                2920.56       ST53
# 2                   0.02                                2174.04       ST18
# 3                   0.02                                2299.78       ST35
# 4                   0.02                                1953.53       ST48
#
#   abbreviation  cocrmcyasst  cocrmcytotc  studentteacherratio  \
# 0           PA         79.0         83.0                 14.0
# 1           WA         59.0        127.0                 21.0
# 2           IN         41.0        119.0                 17.0
# 3           NM         98.0         89.0                 16.0
# 4           TX        109.0        122.0                 15.0
#
#                  id                    name   type  value  \
# 0  1600000US4224000      Erie, Pennsylvania  place   86.4
# 1  1600000US5357745      Renton, Washington  place   91.2
# 2  1600000US1871000     South Bend, Indiana  place   83.4
# 3  1600000US3539380  Las Cruces, New Mexico  place   86.8
# 4  1600000US4874144            Tyler, Texas  place   83.5
#
#                                  variable  year
# 0  percent_high_school_graduate_or_higher  2017
# 1  percent_high_school_graduate_or_higher  2017
# 2  percent_high_school_graduate_or_higher  2017
# 3  percent_high_school_graduate_or_higher  2017
# 4  percent_high_school_graduate_or_higher  2017

# %%
schools_all.columns
# Out:
# Index(['State', 'City', 'Population', 'Violent\ncrime', 'Property\ncrime',
#        'Violent Crime per pop', 'Violent crime rate per 100,000 inhabitants',
#        'Property crime per pop', 'Property crime per 100,000 inhabitants',
#        'St_geo_key', 'abbreviation', 'cocrmcyasst', 'cocrmcytotc',
#        'studentteacherratio', 'id', 'name', 'type', 'value', 'variable',
#        'year'],
#       dtype='object')

# %%
#rename column name
schools_all_rename = schools_all.rename(index=str, columns={'Violent\ncrime': 'Violent crime', 
                                                            'Property\ncrime':'Property crime',
                                                            "cocrmcyasst": "Assault Risk (County)",
                                                            "cocrmcytotc": "Total Crime Risk (County)",
                                                            "studentteacherratio": "Student Teacher Ratio",
                                                            "value": "Percent of High School Graduate or Higher"
                                                           })
schools_alldata = schools_all_rename[['State','City','Population','Violent crime','Property crime','Violent Crime per pop',
                                     'Violent crime rate per 100,000 inhabitants','Property crime per pop',
                                     'Property crime per 100,000 inhabitants', 'Assault Risk (County)',
                                     'Total Crime Risk (County)','Student Teacher Ratio',
                                     'Percent of High School Graduate or Higher','year']]
schools_alldata.head()
# Out:
#           State        City Population Violent crime Property crime  \
# 0  Pennsylvania        Erie     98,887           176            959
# 1    Washington      Renton    100,015           148          2,921
# 2       Indiana  South Bend     101240           465           2201
# 3    New Mexico  Las Cruces     102227           126           2351
# 4         Texas       Tyler    102,481           206          2,002
#
#   Violent Crime per pop Violent crime rate per 100,000 inhabitants  \
# 0                     0                                     177.98
# 1                     0                                     147.98
# 2                     0                                      459.3
# 3                     0                                     123.26
# 4                     0                                     201.01
#
#   Property crime per pop Property crime per 100,000 inhabitants  \
# 0                   0.01                                 969.79
# 1                   0.03                                2920.56
# 2                   0.02                                2174.04
# 3                   0.02                                2299.78
# 4                   0.02                                1953.53
#
#    Assault Risk (County)  Total Crime Risk (County)  Student Teacher Ratio  \
# 0                   79.0                       83.0                   14.0
# 1                   59.0                      127.0                   21.0
# 2                   41.0                      119.0                   17.0
# 3                   98.0                       89.0                   16.0
# 4                  109.0                      122.0                   15.0
#
#    Percent of High School Graduate or Higher  year
# 0                                       86.4  2017
# 1                                       91.2  2017
# 2                                       83.4  2017
# 3                                       86.8  2017
# 4                                       83.5  2017

# %%
#output the data set for analysis
outputfile = "Full Data For Analysis.csv"
schools_alldata.to_csv(outputfile)
